# %% [markdown]
# <a href="https://colab.research.google.com/github/ankitkparashar/python/blob/main/CSML/Module1/Week1/Jiao_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World!')

hello_world_string = "Hello World!"
print(hello_world_string)
# Out:
# Hello World!
# Hello World!

# %%
print("Variable Assignment")

a0_var = 3
A0_var = 4

print("Variable a0_var assigned value:", a0_var)
print("Variable A0_var assigned value:", A0_var)
# Out:
# Variable Assignment
# Variable a0_var assigned value: 3
# Variable A0_var assigned value: 4

# %%
x = 2
print("The type of x is:", type(x))

y = 2.5
print("The type of y is:", type(y))

z = "Hello World!"
print("The type of z is:", type(z))
# Out:
# The type of x is: <class 'int'>
# The type of y is: <class 'float'>
# The type of z is: <class 'str'>

# %%
#Addition, subtraction, multiplication, exponentiation

print("x + 3 is", x + 3)
print("x - 15 is", x - 15)
print("x * 3 is", x * 3)
print("x / 2 is", x / 2)
print("x // 2 (floor division) is", x // 2)
print("x mod 2 (remainder) is", x % 2)
print("x ** 3 (exponentiation) is", x ** 3)

x += 1
print("x += 1 is", x)
x *= 2
print("x *= 2 is", x)
# Out:
# x + 3 is 5
# x - 15 is -13
# x * 3 is 6
# x / 2 is 1.0
# x // 2 (floor division) is 1
# x mod 2 (remainder) is 0
# x ** 3 (exponentiation) is 8
# x += 1 is 3
# x *= 2 is 6
